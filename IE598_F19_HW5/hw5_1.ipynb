# %%
import pandas as pd
import sys
import matplotlib.pyplot as plt
import seaborn as sns

# Read in file
df = pd.read_csv('hw5_treasury yield curve data.csv')

# Get the row and column number
ROW = df.shape[0]
COL = df.shape[1]
print("Number of Rows of Data = " + str(ROW))
print("Number of Columns of Data = " + str(COL) + '\n')

df.head()
# Out:
# Number of Rows of Data = 8635
# Number of Columns of Data = 32
#         Date  SVENF01  SVENF02  SVENF03  SVENF04  SVENF05  SVENF06  SVENF07  \
# 0  5/17/2019   2.1224   2.0266   2.1023   2.2377   2.3790   2.5042   2.6069
# 1  5/16/2019   2.1239   2.0317   2.1096   2.2468   2.3901   2.5171   2.6217
# 2  5/15/2019   2.0874   1.9956   2.0844   2.2289   2.3736   2.4980   2.5984
# 3  5/14/2019   2.1319   2.0559   2.1451   2.2856   2.4257   2.5461   2.6428
# 4  5/13/2019   2.1051   2.0234   2.1180   2.2632   2.4051   2.5248   2.6198
#
#    SVENF08  SVENF09  ...  SVENF22  SVENF23  SVENF24  SVENF25  SVENF26  \
# 0   2.6885   2.7530  ...   3.3355   3.3876   3.4400   3.4925   3.5446
# 1   2.7049   2.7710  ...   3.3574   3.4091   3.4610   3.5130   3.5646
# 2   2.6779   2.7418  ...   3.3589   3.4086   3.4575   3.5055   3.5524
# 3   2.7188   2.7791  ...   3.3940   3.4485   3.5029   3.5568   3.6099
# 4   2.6940   2.7532  ...   3.3712   3.4227   3.4735   3.5234   3.5722
#
# ...

# %%
# Remove missing values
df=df.dropna()

print("Data types in 'df': ")
print(df.dtypes, "\n")

print("Missing data in 'df': ")
print(df.isnull().sum(), "\n")

# Displays the number of times each specific value of 'MEDV' in 'df'
df['Adj_Close'].value_counts()
# Out:
# Data types in 'df':
# Date          object
# SVENF01      float64
# SVENF02      float64
# SVENF03      float64
# SVENF04      float64
# SVENF05      float64
# SVENF06      float64
# SVENF07      float64
# SVENF08      float64
# SVENF09      float64
# SVENF10      float64
# SVENF11      float64
# SVENF12      float64
# SVENF13      float64
# SVENF14      float64
# SVENF15      float64
# SVENF16      float64
# SVENF17      float64
# SVENF18      float64
# SVENF19      float64
# SVENF20      float64
# SVENF21      float64
# SVENF22      float64
# SVENF23      float64
# SVENF24      float64
# SVENF25      float64
# SVENF26      float64
# SVENF27      float64
# SVENF28      float64
# SVENF29      float64
# SVENF30      float64
# Adj_Close    float64
# dtype: object
#
# Missing data in 'df':
# Date         0
# SVENF01      0
# SVENF02      0
# SVENF03      0
# SVENF04      0
# SVENF05      0
# SVENF06      0
# SVENF07      0
# SVENF08      0
# SVENF09      0
# SVENF10      0
# ...

# %%
# Show graphical summary of the relationships in 'df'
cols = ['SVENF01', 'SVENF07', 'SVENF13', 'SVENF24', 'SVENF30']
sns.pairplot(df[cols], size=2.5)
plt.tight_layout()
plt.show()

# %%
import numpy as np

# Respective linear correlations table
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale=1)
hm = sns.heatmap(cm,cbar=True,annot=True,square=True,fmt='.2f',annot_kws={'size': 15},yticklabels=cols, xticklabels=cols)           
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

_ = sns.swarmplot(x='SVENF07', y='Adj_Close', data=df)
# Label the axes
_ = plt.xlabel('SVENF07')
_ = plt.ylabel('Adj_Close')
# Show the plot
plt.show()

_ = sns.swarmplot(x='SVENF24', y='Adj_Close', data=df)
# Label the axes
_ = plt.xlabel('SVENF24')
_ = plt.ylabel('Adj_Close')
# Show the plot
plt.show()

# %%
# covariance for SVENF07 and SVENF24
cov_matrix = np.cov(df['SVENF07'], df['Adj_Close'])
print('covariance between SVENF07 and Adj_Close: %.4f' % (cov_matrix[0,1]))

cov_matrix = np.cov(df['SVENF24'], df['Adj_Close'])
print('\ncovariance between SVENF24 and Adj_Close: %.4f' % (cov_matrix[0,1]))
# Out:
# covariance between SVENF07 and Adj_Close: -4.5807
#
# covariance between SVENF24 and Adj_Close: -3.7554

# %%
print("My name is Xin Wang")
print("My NetID is: xinw9")
print("I hereby certify that I have read the University policy on Academic Integrity and that I am not in violation.")
